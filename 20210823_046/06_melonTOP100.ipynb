# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
targetSite = 'https://www.melon.com/chart/index.htm'
request = requests.get(targetSite)
# 406(허용되지 않음): 요청한 페이지가 요청한 콘텐츠 특성으로 응답할 수 없다.
print(request) # <Response [406]>
# Out:
# <Response [406]>

# %%
targetSite = 'https://www.melon.com/chart/index.htm'
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
request = requests.get(targetSite, headers=header)
print(request)
# Out:
# <Response [200]>

# %%
html = request.text
soup = BeautifulSoup(html, 'html.parser')
# print(soup)

# %%
# 노래 제목 크롤링
titles = soup.findAll('div', {'class': 'ellipsis rank01'})
# print(titles)
# print(len(titles))

for i in range(len(titles)):
    # print('{0:3d}위 {1}'.format(i + 1, titles[i].text.strip()))
    # print('{0:3d}위 {1}'.format(i + 1, titles[i].text.split('\n')[1]))
    print('{0:3d}위 {1}'.format(i + 1, titles[i].text.strip().split('\n')[0]))
# Out:
#   1위 신호등
#   2위 바라만 본다
#   3위 낙하 (with 아이유)
#   4위 Next Level
#   5위 Queendom
#   6위 Permission to Dance
#   7위 Weekend
#   8위 STAY
#   9위 Butter
#  10위 DUMB DUMB
#  11위 OHAYO MY NIGHT
#  12위 좋아좋아
#  13위 헤픈 우연
#  14위 Peaches (Feat. Daniel Caesar & Giveon)
#  15위 Bad Habits
#  16위 비와 당신
#  17위 Dynamite
#  18위 Dun Dun Dance
#  19위 롤린 (Rollin')
#  20위 이제 나만 믿어요
#  21위 비가 오는 날엔 (2021)
#  22위 라일락
#  23위 여전히 아름다운지
#  24위 치맛바람 (Chi Mat Ba Ram)
#  25위 Alcohol-Free
#  26위 Celebrity
#  27위 하루만 더
#  28위 안녕 (Hello)
#  29위 다정히 내 이름을 부르면
#  30위 ASAP
#  31위 별빛 같은 나의 사랑아
#  32위 사진을 보다가
#  33위 나를 아는 사람
#  34위 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
#  35위 HERO
#  36위 Savage Love (Laxed - Siren Beat) (BTS Remix)
#  37위 가을 우체국 앞에서
#  38위 운전만해 (We Ride)
#  39위 그대라는 사치
#  40위 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  41위 다시 사랑한다면 (김필 Ver.)
#  42위 상상더하기
#  43위 회상
#  44위 끝사랑
#  45위 밝게 빛나는 별이 되어 비춰줄게
#  46위 Bk Love
#  47위 내 손을 잡아
#  48위 Timeless
#  49위 잊었니
#  50위 이젠 잊기로 해요 (Drama Ver.)
#  51위 네 노래
#  52위 멜로디
#  53위 봄날
#  54위 슈퍼스타
#  55위 Life Goes On
#  56위 고백
#  57위 밤하늘의 별을(2020)
#  58위 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  59위 상상더하기
#  60위 미워요
#  61위 Lovesick Girls
#  62위 Off My Face
#  63위 계단말고 엘리베이터
#  64위 사랑의 아픔 딛고
#  65위 어푸 (Ah puh)
#  66위 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  67위 추억은 만남보다 이별에 남아
#  68위 아로하
#  69위 Blueming
#  70위 제자리 걸음
#  71위 잠이 오질 않네요
#  72위 넌 좋은 사람
#  73위 목로주점
#  74위 에잇(Prod.&Feat. SUGA of BTS)
#  75위 Dolphin
#  76위 LO$ER=LO♡ER
#  77위 그날에 나는 맘이 편했을까
#  78위 허리춤
#  79위 취기를 빌려 (취향저격 그녀 X 산들)
#  80위 고백
#  81위 LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
#  82위 2002
#  83위 라라라
#  84위 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  85위 METEOR
#  86위 너에게
#  87위 나는 너 좋아
#  88위 모든 날, 모든 순간 (Every day, Every Moment)
#  89위 12:45 (Stripped)
#  90위 오래된 노래
#  91위 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
#  92위 VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
#  93위 너의 번호를 누르고 (Prod. 영화처럼)
#  94위 Coin
#  95위 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
#  96위 어떻게 지내 (Prod. By VAN.C)
#  97위 벌써 일년 (Drama Ver.)
#  98위 On The Ground
#  99위 사실 나는 (Feat.전건호)
# 100위 Memories

# %%
# 아티스트 크롤링
artists = soup.findAll('span', {'class', 'checkEllipsis'})
# print(artists)
# print(len(artists))

for i in range(len(artists)):
    # print('{0:3d}위 {1}'.format(i + 1, artists[i].text.strip()))
    # print('{0:3d}위 {1}'.format(i + 1, artists[i].text.split('\n')[0]))
    print('{0:3d}위 {1}'.format(i + 1, artists[i].text.strip().split('\n')[0]))
# Out:
#   1위 이무진
#   2위 MSG워너비(M.O.M)
#   3위 AKMU (악뮤)
#   4위 aespa
#   5위 Red Velvet (레드벨벳)
#   6위 방탄소년단
#   7위 태연 (TAEYEON)
#   8위 The Kid LAROI, Justin Bieber
#   9위 방탄소년단
#  10위 전소미
#  11위 디핵 (D-Hack), PATEKO (파테코)
#  12위 조정석
#  13위 헤이즈 (Heize)
#  14위 Justin Bieber
#  15위 Ed Sheeran
#  16위 이무진
#  17위 방탄소년단
#  18위 오마이걸 (OH MY GIRL)
#  19위 브레이브걸스
#  20위 임영웅
#  21위 헤이즈 (Heize)
#  22위 아이유
#  23위 세븐틴
#  24위 브레이브걸스
#  25위 TWICE (트와이스)
#  26위 아이유
#  27위 빅마마
#  28위 조이 (JOY)
#  29위 경서예지, 전건호
#  30위 STAYC(스테이씨)
#  31위 임영웅
#  32위 다비치
#  33위 MSG워너비(정상동기)
#  34위 호미들
#  35위 임영웅
#  36위 Jawsh 685, Jason Derulo, 방탄소년단
#  37위 김대명
#  38위 브레이브걸스
#  39위 임영웅
#  40위 방탄소년단
#  41위 임영웅
#  42위 라붐 (LABOUM)
#  43위 정경호
#  44위 임영웅
#  45위 송이한
#  46위 임영웅
#  47위 아이유
#  48위 SG 워너비
#  49위 임영웅
#  50위 미도와 파라솔
#  51위 피아노맨
#  52위 ASH ISLAND
#  53위 방탄소년단
#  54위 미도와 파라솔
#  55위 방탄소년단
#  56위 10CM
#  57위 경서
#  58위 에픽하이 (EPIK HIGH)
#  59위 MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인)
#  60위 임영웅
#  61위 BLACKPINK
#  62위 Justin Bieber
#  63위 임영웅
#  64위 임영웅
#  65위 아이유
#  66위 AKMU (악뮤)
#  67위 정동하
#  68위 조정석
#  69위 아이유
#  70위 V.O.S
#  71위 장범준
#  72위 SG 워너비
#  73위 임영웅
#  74위 아이유
#  75위 오마이걸 (OH MY GIRL)
#  76위 투모로우바이투게더
#  77위 이예준
#  78위 오반 (OVAN)
#  79위 산들
#  80위 장범준
#  81위 양요섭, 정은지
#  82위 Anne-Marie
#  83위 SG 워너비
#  84위 장범준
#  85위 창모 (CHANGMO)
#  86위 유연석
#  87위 장범준
#  88위 폴킴
#  89위 Etham
#  90위 스탠딩 에그
#  91위 적재
#  92위 미란이 (Mirani), 먼치맨(MUNCHMAN), Khundi Panda, 머쉬베놈 (MUSHVENOM)
#  93위 #안녕
#  94위 아이유
#  95위 마크툽 (MAKTUB)
#  96위 오반 (OVAN)
#  97위 미도와 파라솔
#  98위 로제 (ROSÉ)
#  99위 경서예지
# 100위 Maroon 5

# %%
print(dt.now())
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    print('{0:3d}위 {1} - {2}'.format(i + 1, artist, title))
# Out:
# 2021-08-23 09:50:04.176884
#   1위 이무진 - 신호등
#   2위 MSG워너비(M.O.M) - 바라만 본다
#   3위 AKMU (악뮤) - 낙하 (with 아이유)
#   4위 aespa - Next Level
#   5위 Red Velvet (레드벨벳) - Queendom
#   6위 방탄소년단 - Permission to Dance
#   7위 태연 (TAEYEON) - Weekend
#   8위 The Kid LAROI, Justin Bieber - STAY
#   9위 방탄소년단 - Butter
#  10위 전소미 - DUMB DUMB
#  11위 디핵 (D-Hack), PATEKO (파테코) - OHAYO MY NIGHT
#  12위 조정석 - 좋아좋아
#  13위 헤이즈 (Heize) - 헤픈 우연
#  14위 Justin Bieber - Peaches (Feat. Daniel Caesar & Giveon)
#  15위 Ed Sheeran - Bad Habits
#  16위 이무진 - 비와 당신
#  17위 방탄소년단 - Dynamite
#  18위 오마이걸 (OH MY GIRL) - Dun Dun Dance
#  19위 브레이브걸스 - 롤린 (Rollin')
#  20위 임영웅 - 이제 나만 믿어요
#  21위 헤이즈 (Heize) - 비가 오는 날엔 (2021)
#  22위 아이유 - 라일락
#  23위 세븐틴 - 여전히 아름다운지
#  24위 브레이브걸스 - 치맛바람 (Chi Mat Ba Ram)
#  25위 TWICE (트와이스) - Alcohol-Free
#  26위 아이유 - Celebrity
#  27위 빅마마 - 하루만 더
#  28위 조이 (JOY) - 안녕 (Hello)
#  29위 경서예지, 전건호 - 다정히 내 이름을 부르면
#  30위 STAYC(스테이씨) - ASAP
#  31위 임영웅 - 별빛 같은 나의 사랑아
#  32위 다비치 - 사진을 보다가
#  33위 MSG워너비(정상동기) - 나를 아는 사람
#  34위 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
#  35위 임영웅 - HERO
#  36위 Jawsh 685, Jason Derulo, 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  37위 김대명 - 가을 우체국 앞에서
#  38위 브레이브걸스 - 운전만해 (We Ride)
#  39위 임영웅 - 그대라는 사치
#  40위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  41위 임영웅 - 다시 사랑한다면 (김필 Ver.)
#  42위 라붐 (LABOUM) - 상상더하기
#  43위 정경호 - 회상
#  44위 임영웅 - 끝사랑
#  45위 송이한 - 밝게 빛나는 별이 되어 비춰줄게
#  46위 임영웅 - Bk Love
#  47위 아이유 - 내 손을 잡아
#  48위 SG 워너비 - Timeless
#  49위 임영웅 - 잊었니
#  50위 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
#  51위 피아노맨 - 네 노래
#  52위 ASH ISLAND - 멜로디
#  53위 방탄소년단 - 봄날
#  54위 미도와 파라솔 - 슈퍼스타
#  55위 방탄소년단 - Life Goes On
#  56위 10CM - 고백
#  57위 경서 - 밤하늘의 별을(2020)
#  58위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  59위 MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인) - 상상더하기
#  60위 임영웅 - 미워요
#  61위 BLACKPINK - Lovesick Girls
#  62위 Justin Bieber - Off My Face
#  63위 임영웅 - 계단말고 엘리베이터
#  64위 임영웅 - 사랑의 아픔 딛고
#  65위 아이유 - 어푸 (Ah puh)
#  66위 AKMU (악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  67위 정동하 - 추억은 만남보다 이별에 남아
#  68위 조정석 - 아로하
#  69위 아이유 - Blueming
#  70위 V.O.S - 제자리 걸음
#  71위 장범준 - 잠이 오질 않네요
#  72위 SG 워너비 - 넌 좋은 사람
#  73위 임영웅 - 목로주점
#  74위 아이유 - 에잇(Prod.&Feat. SUGA of BTS)
#  75위 오마이걸 (OH MY GIRL) - Dolphin
#  76위 투모로우바이투게더 - LO$ER=LO♡ER
#  77위 이예준 - 그날에 나는 맘이 편했을까
#  78위 오반 (OVAN) - 허리춤
#  79위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#  80위 장범준 - 고백
#  81위 양요섭, 정은지 - LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
#  82위 Anne-Marie - 2002
#  83위 SG 워너비 - 라라라
#  84위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  85위 창모 (CHANGMO) - METEOR
#  86위 유연석 - 너에게
#  87위 장범준 - 나는 너 좋아
#  88위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
#  89위 Etham - 12:45 (Stripped)
#  90위 스탠딩 에그 - 오래된 노래
#  91위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
#  92위 미란이 (Mirani), 먼치맨(MUNCHMAN), Khundi Panda, 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
#  93위 #안녕 - 너의 번호를 누르고 (Prod. 영화처럼)
#  94위 아이유 - Coin
#  95위 마크툽 (MAKTUB) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
#  96위 오반 (OVAN) - 어떻게 지내 (Prod. By VAN.C)
#  97위 미도와 파라솔 - 벌써 일년 (Drama Ver.)
#  98위 로제 (ROSÉ) - On The Ground
#  99위 경서예지 - 사실 나는 (Feat.전건호)
# 100위 Maroon 5 - Memories

# %%
file = open('./output/melonTOP100.txt', 'w', -1, 'utf-8')
file.write('{} 현재 Melon 뮤직 실시간 TOP 100\n'.format(dt.now()))
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    file.write('{0:3d}위 {1} - {2}\n'.format(i + 1, artist, title))
file.close()
print('melonTOP100.txt 파일로 쓰기 완료')
# Out:
# melonTOP100.txt 파일로 쓰기 완료

# %%
try:
    file = open('./output/melonTOP100.txt', 'r', -1, 'utf-8')
    lines = file.readlines()
    for line in lines:
        print(line.strip())
except FileNotFoundError:
    print('디스크에 파일이 없습니다.')
# Out:
# 2021-08-23 10:01:55.746716 현재 Melon 뮤직 실시간 TOP 100
# 1위 이무진 - 신호등
# 2위 MSG워너비(M.O.M) - 바라만 본다
# 3위 AKMU (악뮤) - 낙하 (with 아이유)
# 4위 aespa - Next Level
# 5위 Red Velvet (레드벨벳) - Queendom
# 6위 방탄소년단 - Permission to Dance
# 7위 태연 (TAEYEON) - Weekend
# 8위 The Kid LAROI, Justin Bieber - STAY
# 9위 방탄소년단 - Butter
# 10위 전소미 - DUMB DUMB
# 11위 디핵 (D-Hack), PATEKO (파테코) - OHAYO MY NIGHT
# 12위 조정석 - 좋아좋아
# 13위 헤이즈 (Heize) - 헤픈 우연
# 14위 Justin Bieber - Peaches (Feat. Daniel Caesar & Giveon)
# 15위 Ed Sheeran - Bad Habits
# 16위 이무진 - 비와 당신
# 17위 방탄소년단 - Dynamite
# 18위 오마이걸 (OH MY GIRL) - Dun Dun Dance
# 19위 브레이브걸스 - 롤린 (Rollin')
# 20위 임영웅 - 이제 나만 믿어요
# 21위 헤이즈 (Heize) - 비가 오는 날엔 (2021)
# 22위 아이유 - 라일락
# 23위 세븐틴 - 여전히 아름다운지
# 24위 브레이브걸스 - 치맛바람 (Chi Mat Ba Ram)
# 25위 TWICE (트와이스) - Alcohol-Free
# 26위 아이유 - Celebrity
# 27위 빅마마 - 하루만 더
# 28위 조이 (JOY) - 안녕 (Hello)
# 29위 경서예지, 전건호 - 다정히 내 이름을 부르면
# 30위 STAYC(스테이씨) - ASAP
# 31위 임영웅 - 별빛 같은 나의 사랑아
# 32위 다비치 - 사진을 보다가
# 33위 MSG워너비(정상동기) - 나를 아는 사람
# 34위 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
# 35위 임영웅 - HERO
# 36위 Jawsh 685, Jason Derulo, 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
# 37위 김대명 - 가을 우체국 앞에서
# 38위 브레이브걸스 - 운전만해 (We Ride)
# 39위 임영웅 - 그대라는 사치
# 40위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 41위 임영웅 - 다시 사랑한다면 (김필 Ver.)
# 42위 라붐 (LABOUM) - 상상더하기
# 43위 정경호 - 회상
# 44위 임영웅 - 끝사랑
# 45위 송이한 - 밝게 빛나는 별이 되어 비춰줄게
# 46위 임영웅 - Bk Love
# 47위 아이유 - 내 손을 잡아
# 48위 SG 워너비 - Timeless
# 49위 임영웅 - 잊었니
# 50위 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
# 51위 피아노맨 - 네 노래
# 52위 ASH ISLAND - 멜로디
# 53위 방탄소년단 - 봄날
# 54위 미도와 파라솔 - 슈퍼스타
# 55위 방탄소년단 - Life Goes On
# 56위 10CM - 고백
# 57위 경서 - 밤하늘의 별을(2020)
# 58위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 59위 MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인) - 상상더하기
# 60위 임영웅 - 미워요
# 61위 BLACKPINK - Lovesick Girls
# 62위 Justin Bieber - Off My Face
# 63위 임영웅 - 계단말고 엘리베이터
# 64위 임영웅 - 사랑의 아픔 딛고
# 65위 아이유 - 어푸 (Ah puh)
# 66위 AKMU (악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 67위 정동하 - 추억은 만남보다 이별에 남아
# 68위 조정석 - 아로하
# 69위 아이유 - Blueming
# 70위 V.O.S - 제자리 걸음
# 71위 장범준 - 잠이 오질 않네요
# 72위 SG 워너비 - 넌 좋은 사람
# 73위 임영웅 - 목로주점
# 74위 아이유 - 에잇(Prod.&Feat. SUGA of BTS)
# 75위 오마이걸 (OH MY GIRL) - Dolphin
# 76위 투모로우바이투게더 - LO$ER=LO♡ER
# 77위 이예준 - 그날에 나는 맘이 편했을까
# 78위 오반 (OVAN) - 허리춤
# 79위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
# 80위 장범준 - 고백
# 81위 양요섭, 정은지 - LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
# 82위 Anne-Marie - 2002
# 83위 SG 워너비 - 라라라
# 84위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 85위 창모 (CHANGMO) - METEOR
# 86위 유연석 - 너에게
# 87위 장범준 - 나는 너 좋아
# 88위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
# 89위 Etham - 12:45 (Stripped)
# 90위 스탠딩 에그 - 오래된 노래
# 91위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 92위 미란이 (Mirani), 먼치맨(MUNCHMAN), Khundi Panda, 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
# 93위 #안녕 - 너의 번호를 누르고 (Prod. 영화처럼)
# 94위 아이유 - Coin
# 95위 마크툽 (MAKTUB) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 96위 오반 (OVAN) - 어떻게 지내 (Prod. By VAN.C)
# 97위 미도와 파라솔 - 벌써 일년 (Drama Ver.)
# 98위 로제 (ROSÉ) - On The Ground
# 99위 경서예지 - 사실 나는 (Feat.전건호)
# 100위 Maroon 5 - Memories
