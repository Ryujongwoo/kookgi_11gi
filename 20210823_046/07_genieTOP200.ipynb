# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt
import time

# %%
# 타겟 사이트 주소 만들기
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210823&hh=10&rtm=Y&pg=1 =>   1 ~  50
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210823&hh=10&rtm=Y&pg=2 =>  51 ~ 100
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210823&hh=10&rtm=Y&pg=3 => 101 ~ 150
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210823&hh=10&rtm=Y&pg=4 => 151 ~ 200
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210823&hh=10&rtm=Y&pg='
for i in range(1, 5):
    # targetSite = url + str(i)
    targetSite = '{}{}'.format(url, i)
    print(targetSite)
# Out:
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210823&hh=10&rtm=Y&pg=1
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210823&hh=10&rtm=Y&pg=2
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210823&hh=10&rtm=Y&pg=3
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210823&hh=10&rtm=Y&pg=4

# %%
# 노래 제목 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210823&hh=10&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    # print(request)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    # print(soup)
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    # print(titles)
    # print(len(titles))
    
    for i in range(len(titles)):
        # print('{0:3d}위 {1}'.format(i + 1, titles[i].text.strip()))
        # print('{0:3d}위 {1}'.format(i + 1, titles[i].text.split('\n')[-1].strip()))
        print('{0:3d}위 {1}'.format(i + 1, titles[i].text.strip().split('\n')[0]))
# Out:
#   1위 Stay
#   2위 신호등
#   3위 Queendom
#   4위 낙하 (With 아이유)
#   5위 바라만 본다
#   6위 OHAYO MY NIGHT
#   7위 Permission to Dance
#   8위 Next Level
#   9위 Weekend
#  10위 좋아좋아
#  11위 Bad Habits
#  12위 Butter
#  13위 DUMB DUMB
#  14위 비와 당신
#  15위 사진을 보다가
#  16위 비가 오는 날엔 (2021)
#  17위 Peaches (Feat. Daniel Caesar & Giveon)
#  18위 헤픈 우연
#  19위 Dynamite
#  20위 이제 나만 믿어요
#  21위 고백
#  22위 하루만 더
#  23위 롤린 (Rollin')
#  24위 치맛바람 (Chi Mat Ba Ram)
#  25위 라일락
#  26위 다시 사랑한다면 (김필 Ver.)
#  27위 별빛 같은 나의 사랑아
#  28위 HERO
#  29위 여전히 아름다운지
#  30위 Dun Dun Dance
#  31위 다정히 내 이름을 부르면
#  32위 그대라는 사치
#  33위 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  34위 끝사랑
#  35위 Bk Love
#  36위 Savage Love (Laxed - Siren Beat) (BTS Remix)
#  37위 Alcohol-Free
#  38위 잊었니
#  39위 Celebrity
#  40위 미워요
#  41위 가을 우체국 앞에서
#  42위 안녕 (Hello)
#  43위 사랑의 아픔 딛고
#  44위 계단말고 엘리베이터
#  45위 회상
#  46위 나를 아는 사람
#  47위 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  48위 이젠 잊기로 해요 (Drama Ver.)
#  49위 운전만해 (We Ride)
#  50위 목로주점

# %%
# 아티스트 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210823&hh=10&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    # print(request)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    # print(soup)
    
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    # print(artists)
    # print(len(artists))
    
    # i = 0
    # for artist in artists[5:]:
        # print('{0:3d}위 {1}'.format(i + 1, artist.text.strip()))
        # i += 1
    
    # for i in range(len(artists[5:])):
        # print('{0:3d}위 {1}'.format(i + 1, artists[i + 5].text.strip()))
    
    for i in range(5, len(artists)):
        # print('{0:3d}위 {1}'.format(i - 4, artists[i].text.strip()))
        # print('{0:3d}위 {1}'.format(i - 4, artists[i].text.split('\n')[0]))
        print('{0:3d}위 {1}'.format(i - 4, artists[i].text.strip().split('\n')[0]))
# Out:
#   1위 The Kid LAROI & Justin Bieber
#   2위 이무진
#   3위 Red Velvet (레드벨벳)
#   4위 AKMU (악뮤)
#   5위 MSG워너비 (M.O.M)
#   6위 디핵 (D-Hack) & PATEKO
#   7위 태연 (TAEYEON)
#   8위 방탄소년단
#   9위 aespa
#  10위 조정석
#  11위 Ed Sheeran
#  12위 방탄소년단
#  13위 전소미
#  14위 이무진
#  15위 헤이즈 (Heize)
#  16위 Justin Bieber
#  17위 다비치
#  18위 헤이즈 (Heize)
#  19위 방탄소년단
#  20위 임영웅
#  21위 브레이브걸스 (Brave girls)
#  22위 아이유 (IU)
#  23위 빅마마 (Big Mama)
#  24위 10CM
#  25위 브레이브걸스 (Brave girls)
#  26위 에픽하이 (EPIK HIGH)
#  27위 임영웅
#  28위 임영웅
#  29위 임영웅
#  30위 경서예지 & 전건호
#  31위 오마이걸 (OH MY GIRL)
#  32위 임영웅
#  33위 세븐틴 (SEVENTEEN)
#  34위 Jawsh 685 & Jason Derulo & 방탄소년단
#  35위 브레이브걸스 (Brave girls)
#  36위 임영웅
#  37위 아이유 (IU)
#  38위 TWICE (트와이스)
#  39위 MSG워너비 (정상동기)
#  40위 조이 (JOY)
#  41위 임영웅
#  42위 김대명
#  43위 임영웅
#  44위 임영웅
#  45위 조정석
#  46위 라붐 (LABOUM)
#  47위 장범준
#  48위 미도와 파라솔
#  49위 정경호
#  50위 SG워너비

# %%
# 크롤링한 데이터를 리스트에 저장한다.
genie = []
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210823&hh=10&rtm=Y&pg='
header = {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'}
for i in range(1, 5):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    time.sleep(0.5)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    artists = soup.findAll('a', {'class': 'artist ellipsis'})
    
    for j in range(50):
        genie.append(
            (artists[j + 5].text.strip().split('\n')[0], titles[j].text.strip().split('\n')[0])
        )
# print(len(genie))
print(genie)
# Out:
# [('The Kid LAROI & Justin Bieber', 'Stay'), ('이무진', '신호등'), ('Red Velvet (레드벨벳)', 'Queendom'), ('AKMU (악뮤)', '낙하 (With 아이유)'), ('MSG워너비 (M.O.M)', '바라만 본다'), ('디핵 (D-Hack) & PATEKO', 'OHAYO MY NIGHT'), ('태연 (TAEYEON)', 'Weekend'), ('방탄소년단', 'Permission to Dance'), ('aespa', 'Next Level'), ('조정석', '좋아좋아'), ('Ed Sheeran', 'Bad Habits'), ('방탄소년단', 'Butter'), ('전소미', 'DUMB DUMB'), ('이무진', '비와 당신'), ('헤이즈 (Heize)', '비가 오는 날엔 (2021)'), ('Justin Bieber', 'Peaches (Feat. Daniel Caesar & Giveon)'), ('다비치', '사진을 보다가'), ('헤이즈 (Heize)', '헤픈 우연'), ('방탄소년단', 'Dynamite'), ('임영웅', '이제 나만 믿어요'), ('브레이브걸스 (Brave girls)', "롤린 (Rollin')"), ('아이유 (IU)', '라일락'), ('빅마마 (Big Mama)', '하루만 더'), ('10CM', '고백'), ('브레이브걸스 (Brave girls)', '치맛바람 (Chi Mat Ba Ram)'), ('에픽하이 (EPIK HIGH)', '비 오는 날 듣기 좋은 노래 (Feat. Colde)'), ('임영웅', '별빛 같은 나의 사랑아'), ('임영웅', 'HERO'), ('임영웅', '다시 사랑한다면 (김필 Ver.)'), ('경서예지 & 전건호', '다정히 내 이름을 부르면'), ('오마이걸 (OH MY GIRL)', 'Dun Dun Dance'), ('임영웅', '그대라는 사치'), ('세븐틴 (SEVENTEEN)', '여전히 아름다운지'), ('Jawsh 685 & Jason Derulo & 방탄소년단', 'Savage Love (Laxed - Siren Beat) (BTS Remix)'), ('브레이브걸스 (Brave girls)', '운전만해 (We Ride)'), ('임영웅', 'Bk Love'), ('아이유 (IU)', 'Celebrity'), ('TWICE (트와이스)', 'Alcohol-Free'), ('MSG워너비 (정상동기)', '나를 아는 사람'), ('조이 (JOY)', '안녕 (Hello)'), ('임영웅', '잊었니'), ('김대명', '가을 우체국 앞에서'), ('임영웅', '끝사랑'), ('임영웅', '미워요'), ('조정석', '아로하'), ('라붐 (LABOUM)', '상상더하기'), ('장범준', '추적이는 여름 비가 되어'), ('미도와 파라솔', '이젠 잊기로 해요 (Drama Ver.)'), ('정경호', '회상'), ('SG워너비', 'Timeless'), ('방탄소년단', '작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)'), ('STAYC (스테이씨)', 'ASAP'), ('미도와 파라솔', '슈퍼스타'), ('아이유 (IU)', '내 손을 잡아'), ('아이유 (IU)', 'Blueming'), ('Pink Sweat$', 'At My Worst'), ('Justin Bieber', 'Off My Face'), ('호미들', '사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)'), ('아이유 (IU)', '어푸 (Ah puh)'), ('임영웅', '사랑의 아픔 딛고'), ('아이유 (IU)', '에잇 (Prod. & Feat. SUGA of BTS)'), ('임영웅', '목로주점'), ('Anne-Marie', '2002'), ('장범준', '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야'), ('etham', '12 : 45 (Stripped)'), ('송이한', '밝게 빛나는 별이 되어 비춰줄게'), ('MSG워너비', '상상더하기'), ('임영웅', '계단말고 엘리베이터'), ('방탄소년단', 'Life Goes On'), ('방탄소년단', '봄날'), ('ASH ISLAND', '멜로디'), ('폴킴', '모든 날, 모든 순간 (Every day, Every Moment)'), ('AKMU (악뮤)', '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지'), ('경서', '밤하늘의 별을 (2020)'), ('Bruno Mars & Anderson .Paak & Silk Sonic', 'Leave The Door Open'), ('장범준', '나는 너 좋아'), ('Doja Cat', 'Kiss Me More (Feat. SZA)'), ('경서예지', '은하수를 닮은 너에게 (Feat. 몰리디)'), ('BLACKPINK', 'Lovesick Girls'), ('창모 (CHANGMO)', 'METEOR'), ('로꼬 & 이성경', '러브 (Prod. by 로코베리)'), ('피아노맨', '네 노래'), ('이보람 (씨야)', '사랑하니까 (2021)'), ('양요섭 & 정은지', 'LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)'), ('지코 (ZICO)', '아무노래'), ('원슈타인', '밤이 되니까'), ('산들', '취기를 빌려 (취향저격 그녀 X 산들)'), ('SG워너비', '넌 좋은 사람'), ('오마이걸 (OH MY GIRL)', 'Dolphin'), ('김호중', '만개 (Prod. 신지후)'), ('Standing Egg (스탠딩 에그)', '오래된 노래'), ('미도와 파라솔', '벌써 일년 (Drama Ver.)'), ('John K', 'parachute'), ('전미도', '사랑하게 될 줄 알았어'), ('장범준', '잠이 오질 않네요'), ('SG워너비', '라라라'), ('헤이즈 (Heize)', '비도 오고 그래서 (Feat. 신용재)'), ('Maroon 5', 'Memories'), ('미란이 (Mirani) & 먼치맨 (MUNCHMAN) & Khundi Panda & 머쉬베놈 (MUSHVENOM)', 'VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)'), ('오마이걸 (OH MY GIRL)', '살짝 설렜어 (Nonstop)'), ('Tones And I', 'Dance Monkey'), ('PATEKO (파테코)', 'Rainy day (Feat. ASH ISLAND & Skinny Brown)'), ('아이유 (IU)', 'Coin'), ('방탄소년단', 'ON'), ('이예준', '그날에 나는 맘이 편했을까'), ('마크툽 (Maktub)', '오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)'), ('김호중', '나보다 더 사랑해요'), ('조이 (JOY)', '좋은 사람 있으면 소개시켜줘'), ('Sam Ryder', 'Tiny Riot'), ('백지영 & 이홍기 (FT아일랜드)', '다시 사랑할 수 있을까'), ('장범준', '고백'), ('오반 (OVAN)', '허리춤'), ('방탄소년단', 'DNA'), ('폴킴', '안녕'), ('정동하', '추억은 만남보다 이별에 남아'), ('성시경', '너의 모든 순간'), ('Lauv', 'Paris In The Rain'), ('Christopher', 'Bad'), ('김호중', '고맙소'), ('방탄소년단', '소우주 (Mikrokosmos)'), ('유연석', '너에게'), ('Dua Lipa', "Don't Start Now"), ('허각', '우린 어쩌다 헤어진 걸까'), ('방탄소년단', 'IDOL'), ('김호중', '살았소'), ('노을', '늦은 밤 너의 집 앞 골목길에서'), ('AKMU (악뮤)', '전쟁터 (With 이선희)'), ('Ed Sheeran', 'Shape Of You'), ('#안녕', '너의 번호를 누르고 (Prod. by 영화처럼)'), ('로제 (ROSE)', 'On The Ground'), ('아이유  ...

# %%
print(dt.now())
for i in range(200):
    print('{0:3d}위 {1} - {2}'.format(i + 1, genie[i][0], genie[i][1]))
# Out:
# 2021-08-23 13:29:45.178871
#   1위 The Kid LAROI & Justin Bieber - Stay
#   2위 이무진 - 신호등
#   3위 Red Velvet (레드벨벳) - Queendom
#   4위 AKMU (악뮤) - 낙하 (With 아이유)
#   5위 MSG워너비 (M.O.M) - 바라만 본다
#   6위 디핵 (D-Hack) & PATEKO - OHAYO MY NIGHT
#   7위 태연 (TAEYEON) - Weekend
#   8위 방탄소년단 - Permission to Dance
#   9위 aespa - Next Level
#  10위 조정석 - 좋아좋아
#  11위 Ed Sheeran - Bad Habits
#  12위 방탄소년단 - Butter
#  13위 전소미 - DUMB DUMB
#  14위 이무진 - 비와 당신
#  15위 헤이즈 (Heize) - 비가 오는 날엔 (2021)
#  16위 Justin Bieber - Peaches (Feat. Daniel Caesar & Giveon)
#  17위 다비치 - 사진을 보다가
#  18위 헤이즈 (Heize) - 헤픈 우연
#  19위 방탄소년단 - Dynamite
#  20위 임영웅 - 이제 나만 믿어요
#  21위 브레이브걸스 (Brave girls) - 롤린 (Rollin')
#  22위 아이유 (IU) - 라일락
#  23위 빅마마 (Big Mama) - 하루만 더
#  24위 10CM - 고백
#  25위 브레이브걸스 (Brave girls) - 치맛바람 (Chi Mat Ba Ram)
#  26위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  27위 임영웅 - 별빛 같은 나의 사랑아
#  28위 임영웅 - HERO
#  29위 임영웅 - 다시 사랑한다면 (김필 Ver.)
#  30위 경서예지 & 전건호 - 다정히 내 이름을 부르면
#  31위 오마이걸 (OH MY GIRL) - Dun Dun Dance
#  32위 임영웅 - 그대라는 사치
#  33위 세븐틴 (SEVENTEEN) - 여전히 아름다운지
#  34위 Jawsh 685 & Jason Derulo & 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  35위 브레이브걸스 (Brave girls) - 운전만해 (We Ride)
#  36위 임영웅 - Bk Love
#  37위 아이유 (IU) - Celebrity
#  38위 TWICE (트와이스) - Alcohol-Free
#  39위 MSG워너비 (정상동기) - 나를 아는 사람
#  40위 조이 (JOY) - 안녕 (Hello)
#  41위 임영웅 - 잊었니
#  42위 김대명 - 가을 우체국 앞에서
#  43위 임영웅 - 끝사랑
#  44위 임영웅 - 미워요
#  45위 조정석 - 아로하
#  46위 라붐 (LABOUM) - 상상더하기
#  47위 장범준 - 추적이는 여름 비가 되어
#  48위 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
#  49위 정경호 - 회상
#  50위 SG워너비 - Timeless
#  51위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  52위 STAYC (스테이씨) - ASAP
#  53위 미도와 파라솔 - 슈퍼스타
#  54위 아이유 (IU) - 내 손을 잡아
#  55위 아이유 (IU) - Blueming
#  56위 Pink Sweat$ - At My Worst
#  57위 Justin Bieber - Off My Face
#  58위 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)
#  59위 아이유 (IU) - 어푸 (Ah puh)
#  60위 임영웅 - 사랑의 아픔 딛고
#  61위 아이유 (IU) - 에잇 (Prod. & Feat. SUGA of BTS)
#  62위 임영웅 - 목로주점
#  63위 Anne-Marie - 2002
#  64위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  65위 etham - 12 : 45 (Stripped)
#  66위 송이한 - 밝게 빛나는 별이 되어 비춰줄게
#  67위 MSG워너비 - 상상더하기
#  68위 임영웅 - 계단말고 엘리베이터
#  69위 방탄소년단 - Life Goes On
#  70위 방탄소년단 - 봄날
#  71위 ASH ISLAND - 멜로디
#  72위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
#  73위 AKMU (악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  74위 경서 - 밤하늘의 별을 (2020)
#  75위 Bruno Mars & Anderson .Paak & Silk Sonic - Leave The Door Open
 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 166위 Billie Eilish - bad guy
# 167위 폴킴 - 너를 만나
# 168위 아이유 (IU) - Love poem
# 169위 김호중 - 백화 (白花) (Narration. 손숙)
# 170위 김호중 - 우산이 없어요
# 171위 김호중 - 할무니
# 172위 에일리 (AILEE) - 첫눈처럼 너에게 가겠다
# 173위 투모로우바이투게더 - LO$ER=LO♡ER
# 174위 김호중 - 바람남
# 175위 김호중 - 위대한 사랑 (Un Amore Cosi Grande)
# 176위 김호중 - 때
# 177위 허각 - 고백 (바른연애 길잡이 X 허각)
# 178위 태연 (TAEYEON) - 사계 (Four Seasons)
# 179위 방탄소년단 - 불타오르네 (FIRE)
# 180위 김호중 - 너나 나나
# 181위 Alan Walker & Sabrina Carpenter & Farruko - On My Way
# 182위 MSG워너비 (정상동기) - 체념
# 183위 더보이즈 (THE BOYZ) - THRILL RIDE
# 184위 SG워너비 - 살다가
# 185위 선미 - You can't sit with us
# 186위 김호중 - 나만의 길 (My Way)
# 187위 AKMU (악뮤) - 째깍 째깍 째깍 (With Beenzino)
# 188위 Ruel - Painkiller
# 189위 블루 (BLOO) - Downtown Baby
# 190위 aespa - Black Mamba
# 191위 미도와 파라솔 - 너에게 난, 나에게 넌
# 192위 싹쓰리 (유두래곤 & 린다G & 비룡) - 다시 여기 바닷가
# 193위 런치 - Way Back Home (2021)
# 194위 경서 (경서예지) & MJ (써니사이드) - 술 한잔 해요
# 195위 김호중 - 비가 온다
# 196위 24KGoldn - Mood (Feat. Iann Dior)
# 197위 Sam Smith - To Die For
# 198위 SG워너비 - 죄와 벌 (罪와 罰)
# 199위 장범준 - 노래방에서
# 200위 태연 (TAEYEON) - I (Feat. 버벌진트)

# %%
file = open('./output/genieTOP200.txt', 'w', -1, 'utf-8')
file.write('{} 현재 Genie 뮤직 실시간 TOP 200\n'.format(dt.now()))
for i in range(200):
    file.write('{0:3d}위 {1} - {2}\n'.format(i + 1, genie[i][0], genie[i][1]))
file.close()
print('genieTOP200.txt 파일로 쓰기 완료')
# Out:
# genieTOP200.txt 파일로 쓰기 완료

# %%
try:
    file = open('./output/genieTOP200.txt', 'r', -1, 'utf-8')
    lines = file.readlines()
    for line in lines:
        print(line.strip())
except FileNotFoundError:
    print('디스크에 파일이 없습니다.')
# Out:
# 2021-08-23 13:36:41.596170 현재 Genie 뮤직 실시간 TOP 200
# 1위 The Kid LAROI & Justin Bieber - Stay
# 2위 이무진 - 신호등
# 3위 Red Velvet (레드벨벳) - Queendom
# 4위 AKMU (악뮤) - 낙하 (With 아이유)
# 5위 MSG워너비 (M.O.M) - 바라만 본다
# 6위 디핵 (D-Hack) & PATEKO - OHAYO MY NIGHT
# 7위 태연 (TAEYEON) - Weekend
# 8위 방탄소년단 - Permission to Dance
# 9위 aespa - Next Level
# 10위 조정석 - 좋아좋아
# 11위 Ed Sheeran - Bad Habits
# 12위 방탄소년단 - Butter
# 13위 전소미 - DUMB DUMB
# 14위 이무진 - 비와 당신
# 15위 헤이즈 (Heize) - 비가 오는 날엔 (2021)
# 16위 Justin Bieber - Peaches (Feat. Daniel Caesar & Giveon)
# 17위 다비치 - 사진을 보다가
# 18위 헤이즈 (Heize) - 헤픈 우연
# 19위 방탄소년단 - Dynamite
# 20위 임영웅 - 이제 나만 믿어요
# 21위 브레이브걸스 (Brave girls) - 롤린 (Rollin')
# 22위 아이유 (IU) - 라일락
# 23위 빅마마 (Big Mama) - 하루만 더
# 24위 10CM - 고백
# 25위 브레이브걸스 (Brave girls) - 치맛바람 (Chi Mat Ba Ram)
# 26위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 27위 임영웅 - 별빛 같은 나의 사랑아
# 28위 임영웅 - HERO
# 29위 임영웅 - 다시 사랑한다면 (김필 Ver.)
# 30위 경서예지 & 전건호 - 다정히 내 이름을 부르면
# 31위 오마이걸 (OH MY GIRL) - Dun Dun Dance
# 32위 임영웅 - 그대라는 사치
# 33위 세븐틴 (SEVENTEEN) - 여전히 아름다운지
# 34위 Jawsh 685 & Jason Derulo & 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
# 35위 브레이브걸스 (Brave girls) - 운전만해 (We Ride)
# 36위 임영웅 - Bk Love
# 37위 아이유 (IU) - Celebrity
# 38위 TWICE (트와이스) - Alcohol-Free
# 39위 MSG워너비 (정상동기) - 나를 아는 사람
# 40위 조이 (JOY) - 안녕 (Hello)
# 41위 임영웅 - 잊었니
# 42위 김대명 - 가을 우체국 앞에서
# 43위 임영웅 - 끝사랑
# 44위 임영웅 - 미워요
# 45위 조정석 - 아로하
# 46위 라붐 (LABOUM) - 상상더하기
# 47위 장범준 - 추적이는 여름 비가 되어
# 48위 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
# 49위 정경호 - 회상
# 50위 SG워너비 - Timeless
# 51위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 52위 STAYC (스테이씨) - ASAP
# 53위 미도와 파라솔 - 슈퍼스타
# 54위 아이유 (IU) - 내 손을 잡아
# 55위 아이유 (IU) - Blueming
# 56위 Pink Sweat$ - At My Worst
# 57위 Justin Bieber - Off My Face
# 58위 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)
# 59위 아이유 (IU) - 어푸 (Ah puh)
# 60위 임영웅 - 사랑의 아픔 딛고
# 61위 아이유 (IU) - 에잇 (Prod. & Feat. SUGA of BTS)
# 62위 임영웅 - 목로주점
# 63위 Anne-Marie - 2002
# 64위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 65위 etham - 12 : 45 (Stripped)
# 66위 송이한 - 밝게 빛나는 별이 되어 비춰줄게
# 67위 MSG워너비 - 상상더하기
# 68위 임영웅 - 계단말고 엘리베이터
# 69위 방탄소년단 - Life Goes On
# 70위 방탄소년단 - 봄날
# 71위 ASH ISLAND - 멜로디
# 72위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
# 73위 AKMU (악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 74위 경서 - 밤하늘의 별을 (2020)
# 75위 Bruno Mars & Anderson .Paak & Silk Sonic - Leave The Door Open
# 76위 장범준 - 나는 너 좋아
# 77위 Doja Cat - Kiss Me More (Feat. SZA)
# 78위 경서예지 - 은하수를 닮은 너에게 (Feat. 몰리디)
# 79위 BLACKPINK - Lovesick Girls
# 80위 창모 (CHANGMO) - METEOR
# 81위 로꼬 & 이성경 - 러브 (Prod. by 로코베리)
# 82위 피아노맨 - 네 노래
# 83위 이보람 (씨야) - 사랑하니까 (2021)
# 84위 양요섭 & 정은지 - LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
# 85위 지코 (ZICO) - 아무노래
# 86위 원슈타인 - 밤이 되니까
# 87위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
# 88위 SG워너비 - 넌 좋은 사람
# 89위 오마이걸 (OH MY GIRL) - Dolphin
# 90위 김호중 - 만개 (Prod. 신지후)
# 91위 Standing Egg (스탠딩 에그) - 오래된 노래
# 92위 미도와 파라솔 - 벌써 일년 (Drama Ver.)
# 93위 John K - parachute
# 94위 전미도 - 사랑하게 될 줄 알았어
# 95위 장범준 - 잠이 오질 않네요
# 96위 SG워너비 - 라라라
# 97위 헤이즈 (Heize) - 비도 오고 그래서 (Feat. 신용재)
# 98위 Maroon 5 - Memories
# 99위 미란이 (Mirani) & 먼치맨 (MUNCHMAN) & Khundi Panda & 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)
# 100위 오마이걸 (OH MY GIRL) - 살짝 설렜어 (Nonstop)
# 101위 Tones And I - Dance Monkey
# 102위 PATEKO (파테코) - Rainy day (Feat. ASH ISLAND & Skinny Brown)
# 103위 아이유 (IU) - Coin
# 104위 방탄소년단 - ON
# 105위 이예준 - 그날에 나는 맘이 편했을까
# 106위 마크툽 (Maktub) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 107위 김호중 - 나보다 더 사랑해요
# 108위 조이 (JOY) - 좋은 사람 있으면 소개시켜줘
# 109위 Sam Ryder - Tiny Riot
# 110위 백지영 & 이홍기 (FT아일랜드) - 다시 사랑할 수 있을까
# 111위 장범준 - 고백
# 112위 오반 (OVAN) - 허리춤
# 113위 방탄소년단 - DNA
# 114위 폴킴 - 안녕
# 115위 정동하 - 추억은 만남보다 이별에 남아
# 116위 성시경 - 너의 모든 순간
# 117위 Lauv - Paris In The Rain
# 118위 Christopher - Bad
# 119위 김호중 - 고맙소
# 120위 방탄소년단 - 소우주 (Mikrokosmos)
# 121위 유연석 - 너에게
# 122위 Dua Lipa - Don't Start Now
# 123위 허각 - 우린 어쩌다 헤어진 걸까
# 124위 방탄소년단 - IDOL
# 125위 김호중 - 살았소
# 126위 노을 - 늦은 밤 너의 집 앞 골목길에서
#